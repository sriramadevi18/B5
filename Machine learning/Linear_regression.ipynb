# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib

# %%
df = pd.read_csv("F:\\Dataset\\Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
X = df.drop("Sales", axis=1)

# %%
X.shape
# Out:
# (200, 3)

# %%
y = df.Sales

# %%
y.shape
# Out:
# (200,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((160, 3), (40, 3), (160,), (40,))

# %%
scl = StandardScaler()

# %%
x_train_scaled = scl.fit_transform(x_train)

# %%
x_test_scaled = scl.transform(x_test)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 13.87125

# %%
lr.coef_
# Out:
# array([ 4.07686894,  2.76432822, -0.10958854])

# %%
y_pred = lr.predict(x_test_scaled)

# %%
pd.DataFrame({"y_true": y_test, "y_pred": y_pred})
# Out:
#      y_true     y_pred
# 45     14.9  15.188873
# 72      8.8  10.205411
# 40     16.6  16.439320
# 58     23.8  21.808189
# 25     12.0  15.887521
# 13      9.7   8.926802
# 153    19.0  18.135673
# 80     11.8  11.365894
# 3      18.5  17.397555
# 44      8.5   8.669504
# 134    10.8  11.482201
# 149    10.1   9.719351
# 173    11.7  12.139678
# 33     17.4  19.134917
# 62     15.7  16.942065
# 182     8.7   6.527936
# 112    14.1  14.056052
# 129     9.7   7.778336
# 69     22.3  21.095499
# 190    10.8  12.353939
# 133    19.6  19.241405
# 172     7.6   7.511594
# 35     12.8  17.357531
# 157    10.1  10.145578
# 187    17.3  17.142930
# 10      8.6   7.038274
# 104    20.7  20.446466
# 177    11.7  12.243723
# 26     15.0  15.015156
# 171    14.5  14.319856
# 147    25.4  23.188599
# 0      22.1  20.397088
# 109    19.8  19.896170
# 194    17.3  16.522626
# 151    11.6   9.976042
# 82     11.3  10.090430
# 64     18.0  16.858068
# 169    15.0  18.259486
# 4      12.9  13.179382
# 28     18.9  19.538061

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.2564942472809344

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 1.0788802763848646

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8955882331233613

# %%
l1 = Lasso(alpha=0.1)

# %%
l1.fit(x_train_scaled, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
l1.intercept_
# Out:
# 13.87125

# %%
l1.coef_
# Out:
# array([ 3.97459016,  2.62933716, -0.        ])

# %%
y_pred_l1 = l1.predict(x_test_scaled)

# %%
mean_squared_error(y_test, y_pred_l1)
# Out:
# 2.2117440472033407

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8955882331233613

# %%
joblib.dump(lr, "linear.pkl")
# Out:
# ['linear.pkl']

# %%
joblib.dump(scl, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
new_data = [[220,35, 65]]

# %%
LR = joblib.load("linear.pkl")

# %%
Scl = joblib.load("scaler.pkl")

# %%
new_record = Scl.transform(new_data)
# Out:
# C:\Users\amitm\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
LR.predict(new_record)
# Out:
# array([19.42919148])
